# %% [markdown]
# <a href="https://colab.research.google.com/github/sravannaidu/GenAI/blob/main/Pycaret_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/kidney_disease_1.csv')

# %%
df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.shape
# Out:
# (400, 26)

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['classification'] = np.where(df['classification'] == 'ckd', 1, 0)

# %%
df['classification']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 395    0
# 396    0
# 397    0
# 398    0
# 399    0
# Name: classification, Length: 400, dtype: int64

# %%
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 395  395  55.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 395  ...   47  6700  4.9   no  no   no  good  no  no              0
# 396  ...   54  7800  6.2   no  no   no  good  no  no              0
# 397  ...   49  6600  5.4   no  no   no  good  no  no              0
# 398  ...   51  7200  5.9   no  no   no  good  no  no              0
# 399  ...   53  6800  6.1   no  no   no  good  no  no              0
#
# [5 rows x 26 columns]

# %%
data_train = df.sample(frac = 0.8, random_state= 0).reset_index(drop=True)
data_test = df.drop(data_train.index).reset_index(drop = True)

# %%
data_train.shape
# Out:
# (320, 26)

# %%
data_test.shape
# Out:
# (80, 26)

# %%
#!pip install dtale

# %%
#import dtale

# %%
#dtale.show(df)

# %%
#!pip install pycaret

# %%
from pycaret.classification import *

# %%
exp_classification = setup(data = data_train, target = 'classification', session_id = 123)
# Out:
# <style type="text/css">
# #T_b5204_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b5204" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5204_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b5204_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5204_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5204_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b5204_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b5204_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b5204_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b5204_row1_col1" class="data row1 col1" >classification</td>
#     </tr>
#     <tr>
#       <th id="T_b5204_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_6665c th {
#   text-align: left;
# }
# ...

# %%
random_forest = create_model('rf')
# Out:
# <style type="text/css">
# #T_ccba8_row10_col0, #T_ccba8_row10_col1, #T_ccba8_row10_col2, #T_ccba8_row10_col3, #T_ccba8_row10_col4, #T_ccba8_row10_col5, #T_ccba8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ccba8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccba8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ccba8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ccba8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ccba8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ccba8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ccba8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ccba8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_rf = tune_model(random_forest)
# Out:
# <style type="text/css">
# #T_75c5b_row10_col0, #T_75c5b_row10_col1, #T_75c5b_row10_col2, #T_75c5b_row10_col3, #T_75c5b_row10_col4, #T_75c5b_row10_col5, #T_75c5b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_75c5b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75c5b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_75c5b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_75c5b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_75c5b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_75c5b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_75c5b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_75c5b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(tuned_rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_958ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_958ce_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_958ce_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_958ce_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_958ce_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_958ce_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_958ce_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_958ce_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_958ce_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_958ce_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
unseen_predictions = predict_model(tuned_rf, data = data_test)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e9c10" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9c10_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e9c10_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e9c10_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e9c10_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e9c10_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e9c10_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e9c10_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e9c10_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9c10_level0_row0" class="row_heading level0 row0" >0</th>
# ...
